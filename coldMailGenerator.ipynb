# %%
# !pip install langchain-groq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama3-8b-8192", # Changed to a supported model
    temperature=0,
    groq_api_key ='YOUR_API_KEY'
)

res = llm.invoke("the first person to land on moon was ...")
print(res.content)
# Out:
# The first person to walk on the Moon was Neil Armstrong, an American astronaut who stepped out of the lunar module Eagle and onto the Moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the Moon.
#
# However, it's worth noting that Armstrong was not the first person to land on the Moon. That distinction belongs to Edwin "Buzz" Aldrin, who was the second person to walk on the Moon and the first person to land on the Moon's surface. Aldrin stepped out of the lunar module Eagle and onto the Moon's surface about 20 minutes after Armstrong.
#
# The Apollo 11 mission was a historic achievement that marked the first time humans had visited another celestial body. The mission was a culmination of years of hard work and dedication by thousands of people involved in the Apollo program.

# %%
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 78.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://job-boards.greenhouse.io/cloudflare/jobs/6628327?gh_jid=6628327")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Job Application for Systems Engineer, AI Applications Tooling at CloudflareBack to jobsSystems Engineer, AI Applications ToolingHybridApplyAbout Us
#
# At Cloudflare, we are on a mission to help build a better Internet. Today the company runs one of the world’s largest networks that powers millions of websites and other Internet properties for customers ranging from individual bloggers to SMBs to Fortune 500 companies. Cloudflare protects and accelerates any Internet application online without adding hardware, installing software, or changing a line of code. Internet properties powered by Cloudflare all have web traffic routed through its intelligent global network, which gets smarter with every request. As a result, they see significant improvement in performance and a decrease in spam and other attacks. Cloudflare was named to Entrepreneur Magazine’s Top Company Cultures list and ranked among the World’s Most Innovative Companies by Fast Company.
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):
        """
)

chain_extract = prompt_extract | llm
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Systems Engineer, AI Applications Tooling',
#  'experience': "Experience building LLM-powered applications, developer tools, or agent frameworks. Familiarity with Cloudflare's developer platform, edge computing, or AI inference.",
#  'skills': "LLMs, model inference, AI-powered developer tools, Cloudflare's developer platform, edge computing",
#  'description': 'As a member of the AI Applications team, you’ll help shape the future of AI-powered applications on our platform. You’ll work across Cloudflare’s stack, collaborating with teams to define, build, and optimize AI solutions that enhance developer experience, security, and performance.'}

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 99.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 84.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 106.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 18.5 MB/s eta 0:00:00
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:00<00:00, 95.7MiB/s]

# %%
links = collection.query(query_texts=json_res['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/xamarin-portfolio'}]]

# %%
json_res
# Out:
# {'role': 'Systems Engineer, AI Applications Tooling',
#  'experience': "Experience building LLM-powered applications, developer tools, or agent frameworks. Familiarity with Cloudflare's developer platform, edge computing, or AI inference.",
#  'skills': "LLMs, model inference, AI-powered developer tools, Cloudflare's developer platform, edge computing",
#  'description': 'As a member of the AI Applications team, you’ll help shape the future of AI-powered applications on our platform. You’ll work across Cloudflare’s stack, collaborating with teams to define, build, and optimize AI solutions that enhance developer experience, security, and performance.'}

# %%
job = json_res
job['skills']
# Out:
# "LLMs, model inference, AI-powered developer tools, Cloudflare's developer platform, edge computing"

# %%
prompt_email = PromptTemplate.from_template(
    """
    ### JOB DESCRIPTION:
    {job_description}

    ### INSTRUCTION:
    You are Vijay Kaushik, a passionate Full-Stack Developer specializing in building scalable, efficient, and modern web and mobile applications.

    Your technical expertise spans frontend frameworks like React and Angular, backend technologies such as Node.js, Django, and Spring Boot,
    and mobile platforms including Flutter, Android, and iOS. You are also proficient in cloud platforms like Firebase and AWS,
    and DevOps tools such as Docker and Jenkins.

    Your task is to write a personalized cold email to the client based on the job description above.

    In the email:
    - Briefly explain how your skills align with the job requirements.
    - Emphasize how you can contribute value to their team or project.
    - Select and include the **most relevant portfolio links** from the list provided: {link_list}

    End the email professionally with:
    - Your full name
    - Your designation: Full-Stack Developer
    - Your email: vijaykaushik9911@gmail.com

    Do not include any labels or preamble — just the email body.

    ### EMAIL (NO PREAMBLE):
    """
)


chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Excited to Explore Opportunities as a Systems Engineer, AI Applications Tooling
#
# Dear Hiring Manager,
#
# I came across the job description for the Systems Engineer, AI Applications Tooling role at Cloudflare, and I'm thrilled to see how my skills align with the requirements. With my experience in building scalable web and mobile applications, I'm confident that I can contribute value to your team or project.
#
# As a Full-Stack Developer, I've worked with various technologies, including React, Angular, Node.js, Django, Spring Boot, Flutter, Android, and iOS. I'm also proficient in cloud platforms like Firebase and AWS, and DevOps tools like Docker and Jenkins. My proficiency in LLMs, model inference, and AI-powered developer tools makes me a strong candidate for this role.
#
# I'd like to highlight my portfolio, which showcases my expertise in building AI-powered applications. You can explore my portfolio links here: https://example.com/ml-python-portfolio
#
# ...
